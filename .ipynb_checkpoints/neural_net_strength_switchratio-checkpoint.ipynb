# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load data

# %%
filename = 'data_5kpa_cleaned_01052022.csv'
df = pd.read_csv(filename)
df.drop(['Unnamed: 0', 'WIDTH_sub', 'HEIGHT_sub', 'mem_layer'], axis=1, inplace=True)
df_var = df[['WIDTH_mem', 'THICKNESS_mem', 'WIDTH_device', 'HEIGHT_chamber', 'HEIGHT_device', 'Stalk_angle']]
df_perf = df[['strength', 'switching_ratio']]

# %% [markdown]
# ### Neural network ML

# %%
train_X, test_X, train_y, test_y = train_test_split(df_var.values, df_perf.values, 
                                                    test_size=0.2, random_state=33)

# %%
X_train = torch.FloatTensor(train_X)
X_test = torch.FloatTensor(test_X)
y_train = torch.FloatTensor(train_y)
y_test = torch.FloatTensor(test_y)

# %%
class Model(nn.Module):
    def __init__(self, in_features=6, h1=8, h2=9, out_features=2):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)
        self.fc2 = nn.Linear(h1, h2)
        self.out = nn.Linear(h2, out_features)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        return x

# %%
torch.manual_seed(11)
model = Model()

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 1000
losses = []

for i in range(epochs):
    i += 1
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)
    losses.append(loss)
    
    if i%100 == 0:
        print(f'epoch: {i:4}  loss: {loss.item():6.3f}')

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# epoch:  100  loss: 17.965
# epoch:  200  loss:  8.602
# epoch:  300  loss:  4.067
# epoch:  400  loss:  2.672
# epoch:  500  loss:  2.374
# epoch:  600  loss:  2.269
# epoch:  700  loss:  2.172
# epoch:  800  loss:  2.073
# epoch:  900  loss:  1.971
# epoch: 1000  loss:  1.866

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(epochs), losses)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('epoch', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
with torch.no_grad():
    y_val = model(X_test)
    loss = criterion(y_val, y_test)
print(f'{loss:.8f}')
# Out:
# 1.35579693

# %%
plt.subplots(1, 2, figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Strength", fontsize=16)
plt.plot([10, 45], [10, 45], c='red')
plt.scatter(y_test[:,0], y_val[:,0])
plt.xlim((10, 45))
plt.ylim((10, 45))
plt.xlabel('True strength', fontsize=14)
plt.ylabel('Predicted strength', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.subplot(1, 2, 2)
plt.title("Switching ratio", fontsize=16)
plt.plot([0.9, 1.2], [0.9, 1.2], c='red')
plt.scatter(y_test[:,1], y_val[:,1])
plt.xlim((0.9, 1.2))
plt.ylim((0.9, 1.2))
plt.xlabel('True switching ratio', fontsize=14)
plt.ylabel('Predicted switching ratio', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# ### Test with examples

# %%
index_of_choice = 17
with torch.no_grad():
    y_pred = model(X_test[index_of_choice])
print(f'Predicted performances: {y_pred}')
print(f'Ground truth: {y_test[index_of_choice]}')
# Out:
# Predicted performances: tensor([34.1750,  1.0846])
# Ground truth: tensor([35.8119,  1.0765])

# %%
# target = df_var[df_perf['strength']>39]
# target.columns
# plt.subplots(2, 3, figsize=(15, 12))
# i = 1
# for col in target.columns:
#     plt.subplot(2, 3, i)
#     plt.title(col, fontsize=20)
#     plt.scatter(np.arange(len(target)), target[col])
#     plt.axhline(y=df_var[col].mean(), color='red', linestyle='-')
#     plt.axhline(y=df_var[col].mean() - df_var[col].std(), color='green', linestyle='-')
#     plt.axhline(y=df_var[col].mean() + df_var[col].std(), color='green', linestyle='-')
#     plt.axhline(y=df_var[col].max(), color='black', linestyle='-')
#     plt.axhline(y=df_var[col].min(), color='black', linestyle='-')
#     plt.xticks(fontsize=16)
#     plt.yticks(fontsize=16)
#     i += 1
